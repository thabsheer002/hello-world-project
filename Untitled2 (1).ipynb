# %%
import random
print('WELCOME TO GAME WORLD ')
Ans=input(' play Rock Paper Scissor? (Y/N) ')

if Ans.upper()=='Y':
  Data=['R','P','S']
  def playtime():

    print('**** RULES ****')
    print('1.Rock wins against Scissors')
    print('2.Paper wins against Rock')
    print('3.Scissors wins against Paper')
    print('Total Five chances ')
    print('All the best')
    print('The game begins........')
    print('\n'*5)
    print('Choices =',Data)
    n=5
    user=0
    THABU=0


    for i in range (5):

      user_choice=input('My Choice is: ')
      THABU_choice=random.choice(Data)
      print('THABU Choice is :',THABU_choice)

      if user_choice.upper() == THABU_choice.upper():
    
        print('\n'*1)
        print('Me =',user)
        print('THABU =',THABU)
        print('\n'*1)

      else:
        if user_choice.upper() == 'S'and THABU_choice.upper() =='P':
          user+=1
        elif user_choice.upper() == 'P' and THABU_choice.upper() =='R':
          user+=1
        elif user_choice.upper() =='R' and THABU_choice.upper() =='S':
           user+=1
        else:
          THABU+=1

        print('\n'*1)
        print('Me =',user)
        print('THABU =',THABU) 
        print('\n'*1)

    print('\n'*2)
    print('GAME OVER')
    print('*'*10)
    print('TOTAL SCORE')
    print('Me =', user)
    print('THABU =', THABU)

    if user > THABU:
      print('***** CONGRATS ******')
      print('***** YOU ARE THE WINNER *****')
    elif THABU > user:
      print('***** CONGRATS *****')
      print('***** THABU IS THE WINNER *****')
    else:
      print('Its a Tie')
    again=input('Play again Y/N ')
    if again.upper()=='Y':
      playtime()
    else:
      print('Thank you for playing ....')
  playtime()
else:
  print('Thank you')
# Out:
# WELCOME TO GAME WORLD
#  play Rock Paper Scissor? (Y/N) Y
# **** RULES ****
# 1.Rock wins against Scissors
# 2.Paper wins against Rock
# 3.Scissors wins against Paper
# Total Five chances
# All the best
# The game begins........
#
#
#
#
#
#
# Choices = ['R', 'P', 'S']
# My Choice is: P
# THABU Choice is : R
#
#
# Me = 1
# THABU = 0
#
#
# My Choice is: S
# THABU Choice is : S
#
#
# Me = 1
# THABU = 0
#
#
# My Choice is: R
# THABU Choice is : S
#
#
# Me = 2
# THABU = 0
#
#
# My Choice is: P
# THABU Choice is : S
#
#
# Me = 2
# THABU = 1
#
#
# My Choice is: R
# THABU Choice is : S
#
#
# Me = 3
# THABU = 1
#
#
#
#
#
# GAME OVER
# **********
# TOTAL SCORE
# Me = 3
# THABU = 1
# ***** CONGRATS ******
# ***** YOU ARE THE WINNER *****
# Play again Y/N N
# Thank you for playing ....
